# %% [markdown]
# # 🌳 Random Forest Classifier
#
# ## 📌 Objective
# Build a Random Forest model on a real-world dataset and understand ensemble learning.
#
# ## 📊 Dataset
# Wine Dataset (sklearn)
#
# ## ⚙️ Workflow
# 1. Load Dataset
# 2. Preprocess Data
# 3. Train Model
# 4. Evaluate Model
# 5. Use OOB Score
# 6. Analyze Feature Importance

# %%
# ML
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_wine
# Data handling
import pandas as pd

# Evaluation
from sklearn.metrics import accuracy_score, classification_report

# %%
# Load dataset

data = load_wine(as_frame=True)
df = data.frame

df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
# Separate features and target

X = df.drop("target", axis=1)
y = df["target"]

# %%
# Split dataset

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# %% [markdown]
# ## 🌳 Training Random Forest
#
# Random Forest builds multiple decision trees and combines their predictions.

# %%
# Train model

model = RandomForestClassifier(
    n_estimators=100,      # number of trees
    random_state=42
)

model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# %%
# Evaluate model

print("Accuracy:", accuracy_score(y_test, y_pred))

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        15
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54

# %% [markdown]
# ## 🎯 Out Of Bag (OOB) Score
#
# OOB score uses unused samples during training for validation.

# %%
# Enable OOB scoring

model_oob = RandomForestClassifier(
    n_estimators=100,
    oob_score=True,
    random_state=42
)

model_oob.fit(X_train, y_train)

print("OOB Score:", model_oob.oob_score_)
# Out:
# OOB Score: 0.9758064516129032

# %% [markdown]
# ## 📊 Feature Importance
#
# Shows which features contribute most to predictions.

# %%
# Feature importance

feature_importance = pd.Series(
    model.feature_importances_,
    index=X.columns
).sort_values(ascending=False)

feature_importance.head(10)
# Out:
# alcohol                         0.162715
# color_intensity                 0.159719
# flavanoids                      0.156283
# proline                         0.124081
# hue                             0.111019
# od280/od315_of_diluted_wines    0.098852
# total_phenols                   0.042004
# magnesium                       0.034591
# malic_acid                      0.033700
# alcalinity_of_ash               0.028841
# dtype: float64

# %% [markdown]
# ## 📊 Observations
#
# - Random Forest performs very well on real-world datasets
# - OOB score provides quick validation
# - Feature importance gives useful insights

# %% [markdown]
# ## ✅ Conclusion
#
# - Random Forest reduces overfitting compared to Decision Trees
# - Works well for classification tasks
# - Provides both accuracy and interpretability
