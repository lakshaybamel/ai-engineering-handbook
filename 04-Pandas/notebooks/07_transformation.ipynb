# %% [markdown]
# # Data Transformation
#
# After cleaning, we transform data to make it useful for analysis.
#
# We can:<br>
# - create new columns
# - apply logic
# - map values
# - replace values

# %%
import pandas as pd

sales = pd.read_csv("../data/processed/cleaned_sales.csv")
sales.head()
# Out:
#    order_id customer_id     product     category  price  quantity       city  \
# 0      1001        C101      laptop  Electronics  55000         1      Delhi
# 1      1002        C102       phone  Electronics  20000         2     Mumbai
# 2      1003        C103       shoes      Fashion   3000         1       Pune
# 3      1004        C101  headphones  Electronics   2000         3      Delhi
# 4      1005        C104      tshirt      Fashion    800         2  Bangalore
#
#          date
# 0  2024-01-05
# 1  2024-01-06
# 2  2024-01-07
# 3  2024-01-07
# 4  2024-01-08

# %% [markdown]
# ## Creating New Column

# %%
sales["total_amount"] = sales["price"] * sales["quantity"]
sales.head()
# Out:
#    order_id customer_id     product     category  price  quantity       city  \
# 0      1001        C101      laptop  Electronics  55000         1      Delhi
# 1      1002        C102       phone  Electronics  20000         2     Mumbai
# 2      1003        C103       shoes      Fashion   3000         1       Pune
# 3      1004        C101  headphones  Electronics   2000         3      Delhi
# 4      1005        C104      tshirt      Fashion    800         2  Bangalore
#
#          date  total_amount
# 0  2024-01-05         55000
# 1  2024-01-06         40000
# 2  2024-01-07          3000
# 3  2024-01-07          6000
# 4  2024-01-08          1600

# %% [markdown]
# ## Apply Function

# %%
def price_category(price):
    if price > 30000:
        return "High"
    elif price > 5000:
        return "Medium"
    else:
        return "Low"

sales["price_level"] = sales["price"].apply(price_category)
sales.head()
# Out:
#    order_id customer_id     product     category  price  quantity       city  \
# 0      1001        C101      laptop  Electronics  55000         1      Delhi
# 1      1002        C102       phone  Electronics  20000         2     Mumbai
# 2      1003        C103       shoes      Fashion   3000         1       Pune
# 3      1004        C101  headphones  Electronics   2000         3      Delhi
# 4      1005        C104      tshirt      Fashion    800         2  Bangalore
#
#          date  total_amount price_level
# 0  2024-01-05         55000        High
# 1  2024-01-06         40000      Medium
# 2  2024-01-07          3000         Low
# 3  2024-01-07          6000         Low
# 4  2024-01-08          1600         Low

# %% [markdown]
# ## Map Values

# %%
city_codes = {
    "Delhi": "D",
    "Mumbai": "M",
    "Pune": "P",
    "Bangalore": "B",
    "Chennai": "C"
}

sales["city_code"] = sales["city"].map(city_codes)
sales.head()
# Out:
#    order_id customer_id     product     category  price  quantity       city  \
# 0      1001        C101      laptop  Electronics  55000         1      Delhi
# 1      1002        C102       phone  Electronics  20000         2     Mumbai
# 2      1003        C103       shoes      Fashion   3000         1       Pune
# 3      1004        C101  headphones  Electronics   2000         3      Delhi
# 4      1005        C104      tshirt      Fashion    800         2  Bangalore
#
#          date  total_amount price_level city_code
# 0  2024-01-05         55000        High         D
# 1  2024-01-06         40000      Medium         M
# 2  2024-01-07          3000         Low         P
# 3  2024-01-07          6000         Low         D
# 4  2024-01-08          1600         Low         B

# %% [markdown]
# ## Replace Values

# %%
sales["category"] = sales["category"].replace({"Electronics": "Tech"})
sales.head()
# Out:
#    order_id customer_id     product category  price  quantity       city  \
# 0      1001        C101      laptop     Tech  55000         1      Delhi
# 1      1002        C102       phone     Tech  20000         2     Mumbai
# 2      1003        C103       shoes  Fashion   3000         1       Pune
# 3      1004        C101  headphones     Tech   2000         3      Delhi
# 4      1005        C104      tshirt  Fashion    800         2  Bangalore
#
#          date  total_amount price_level city_code
# 0  2024-01-05         55000        High         D
# 1  2024-01-06         40000      Medium         M
# 2  2024-01-07          3000         Low         P
# 3  2024-01-07          6000         Low         D
# 4  2024-01-08          1600         Low         B

# %%
## Convert Column Type

# %%
sales["quantity"] = sales["quantity"].astype(int)
sales.dtypes
# Out:
# order_id        int64
# customer_id       str
# product           str
# category          str
# price           int64
# quantity        int64
# city              str
# date              str
# total_amount    int64
# price_level       str
# city_code         str
# dtype: object

# %% [markdown]
# ## Save Transformed Data

# %%
sales.to_csv("../data/processed/transformed_sales.csv", index=False)

# %% [markdown]
# ## Conclusion
#
# Transformation prepares data for aggregation and analysis.
