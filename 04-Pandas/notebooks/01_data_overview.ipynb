# %% [markdown]
# # Introduction to Data Analysis & EDA
#
# EDA (Exploratory Data Analysis) is the first step of any data science workflow.
#
# Before cleaning or modeling data, we must understand:
#
# - structure of dataset
# - number of records
# - column types
# - missing values
# - patterns in data
#
# In this notebook we only observe — we do NOT modify data.

# %%
# Import pandas
import pandas as pd

# %% [markdown]
# ## Loading Dataset
#
# We start with a small sales dataset.

# %%
# Load CSV file
df = pd.read_csv("../data/raw/sales.csv")

df
# Out:
#    order_id customer_id     product     category  price  quantity       city  \
# 0      1001        C101      Laptop  Electronics  55000         1      Delhi
# 1      1002        C102       Phone  Electronics  20000         2     Mumbai
# 2      1003        C103       Shoes      Fashion   3000         1       Pune
# 3      1004        C101  Headphones  Electronics   2000         3      Delhi
# 4      1005        C104      Tshirt      Fashion    800         2  Bangalore
# 5      1006        C105       Watch  Accessories   2500         1    Chennai
# 6      1007        C102      Laptop  Electronics  60000         1     Mumbai
# 7      1008        C106    Backpack  Accessories   1500         2      Delhi
# 8      1009        C103       Phone  Electronics  18000         1       Pune
# 9      1010        C104       Shoes      Fashion   3500         1  Bangalore
#
#          date
# 0  2024-01-05
# 1  2024-01-06
# 2  2024-01-07
# 3  2024-01-07
# 4  2024-01-08
# 5  2024-01-09
# 6  2024-01-10
# 7  2024-01-10
# 8  2024-01-11
# 9  2024-01-11

# %% [markdown]
# ## Dataset Shape
#
# Shows total rows and columns

# %%
# (rows, columns)
df.shape
# Out:
# (10, 8)

# %% [markdown]
# ## Column Names

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'product', 'category', 'price', 'quantity',
#        'city', 'date'],
#       dtype='str')

# %% [markdown]
# ## First & Last Records

# %%
df.head()
# Out:
#    order_id customer_id     product     category  price  quantity       city  \
# 0      1001        C101      Laptop  Electronics  55000         1      Delhi
# 1      1002        C102       Phone  Electronics  20000         2     Mumbai
# 2      1003        C103       Shoes      Fashion   3000         1       Pune
# 3      1004        C101  Headphones  Electronics   2000         3      Delhi
# 4      1005        C104      Tshirt      Fashion    800         2  Bangalore
#
#          date
# 0  2024-01-05
# 1  2024-01-06
# 2  2024-01-07
# 3  2024-01-07
# 4  2024-01-08

# %%
df.tail()
# Out:
#    order_id customer_id   product     category  price  quantity       city  \
# 5      1006        C105     Watch  Accessories   2500         1    Chennai
# 6      1007        C102    Laptop  Electronics  60000         1     Mumbai
# 7      1008        C106  Backpack  Accessories   1500         2      Delhi
# 8      1009        C103     Phone  Electronics  18000         1       Pune
# 9      1010        C104     Shoes      Fashion   3500         1  Bangalore
#
#          date
# 5  2024-01-09
# 6  2024-01-10
# 7  2024-01-10
# 8  2024-01-11
# 9  2024-01-11

# %% [markdown]
# ## Basic Dataset Information
#
# Shows:<br>
# - data types
# - non-null values
# - memory usage

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     10 non-null     int64
#  1   customer_id  10 non-null     str
#  2   product      10 non-null     str
#  3   category     10 non-null     str
#  4   price        10 non-null     int64
#  5   quantity     10 non-null     int64
#  6   city         10 non-null     str
#  7   date         10 non-null     str
# dtypes: int64(3), str(5)
# memory usage: 772.0 bytes

# %% [markdown]
# ## Statistical Summary
#
# Works only for numeric columns

# %%
df.describe()
# Out:
#          order_id         price   quantity
# count    10.00000     10.000000  10.000000
# mean   1005.50000  16630.000000   1.500000
# std       3.02765  22651.516996   0.707107
# min    1001.00000    800.000000   1.000000
# 25%    1003.25000   2125.000000   1.000000
# 50%    1005.50000   3250.000000   1.000000
# 75%    1007.75000  19500.000000   2.000000
# max    1010.00000  60000.000000   3.000000

# %% [markdown]
# ## Unique Values in Columns

# %%
df["city"].unique()
# Out:
# <StringArray>
# ['Delhi', 'Mumbai', 'Pune', 'Bangalore', 'Chennai']
# Length: 5, dtype: str

# %%
df["category"].unique()
# Out:
# <StringArray>
# ['Electronics', 'Fashion', 'Accessories']
# Length: 3, dtype: str

# %% [markdown]
# ## Value Counts
#
# Frequency of categorical data

# %%
df["category"].value_counts()
# Out:
# category
# Electronics    5
# Fashion        3
# Accessories    2
# Name: count, dtype: int64

# %% [markdown]
# ## Conclusion
#
# EDA helps us understand dataset structure before performing cleaning or transformation.
#
# Next step:<br>
# Working with Series & DataFrame operations.
