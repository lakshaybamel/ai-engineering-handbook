# %% [markdown]
# # GroupBy & Aggregation
#
# After cleaning and transforming data, we summarize it.
#
# GroupBy allows us to answer questions like:<br>
# - Total sales per city
# - Average price per category
# - Orders per product
#
# This step converts raw data → insights.

# %%
import pandas as pd

# Load transformed dataset created in previous notebook
sales = pd.read_csv("../data/processed/transformed_sales.csv")

sales.head()
# Out:
#    order_id customer_id     product category  price  quantity       city  \
# 0      1001        C101      laptop     Tech  55000         1      Delhi
# 1      1002        C102       phone     Tech  20000         2     Mumbai
# 2      1003        C103       shoes  Fashion   3000         1       Pune
# 3      1004        C101  headphones     Tech   2000         3      Delhi
# 4      1005        C104      tshirt  Fashion    800         2  Bangalore
#
#          date  total_amount price_level city_code
# 0  2024-01-05         55000        High         D
# 1  2024-01-06         40000      Medium         M
# 2  2024-01-07          3000         Low         P
# 3  2024-01-07          6000         Low         D
# 4  2024-01-08          1600         Low         B

# %% [markdown]
# ## Grouping Data
#
# We group rows that share common values.

# %%
# Group data by city
sales.groupby("city")

# %% [markdown]
# ## Counting Records per City

# %%
# Number of orders per city
sales.groupby("city")["order_id"].count()
# Out:
# city
# Bangalore    2
# Chennai      1
# Delhi        3
# Mumbai       2
# Pune         2
# Name: order_id, dtype: int64

# %% [markdown]
# ## Total Sales Amount per City

# %%
# Sum of total_amount column city wise
sales.groupby("city")["total_amount"].sum()
# Out:
# city
# Bangalore      5100
# Chennai        2500
# Delhi         64000
# Mumbai       100000
# Pune          21000
# Name: total_amount, dtype: int64

# %% [markdown]
# ## Average Price per Category

# %%
sales.groupby("category")["price"].mean()
# Out:
# category
# Accessories     2000.000000
# Fashion         2433.333333
# Tech           31000.000000
# Name: price, dtype: float64

# %% [markdown]
# ## Multiple Aggregations

# %%
sales.groupby("city")["total_amount"].agg(["sum", "mean", "max"])
# Out:
#               sum          mean    max
# city
# Bangalore    5100   2550.000000   3500
# Chennai      2500   2500.000000   2500
# Delhi       64000  21333.333333  55000
# Mumbai     100000  50000.000000  60000
# Pune        21000  10500.000000  18000

# %% [markdown]
# ## Grouping by Multiple Columns

# %%
sales.groupby(["city", "category"])["total_amount"].sum()
# Out:
# city       category
# Bangalore  Fashion          5100
# Chennai    Accessories      2500
# Delhi      Accessories      3000
#            Tech            61000
# Mumbai     Tech           100000
# Pune       Fashion          3000
#            Tech            18000
# Name: total_amount, dtype: int64

# %% [markdown]
# ## Reset Index (important)

# %%
city_sales = sales.groupby("city")["total_amount"].sum().reset_index()
city_sales
# Out:
#         city  total_amount
# 0  Bangalore          5100
# 1    Chennai          2500
# 2      Delhi         64000
# 3     Mumbai        100000
# 4       Pune         21000

# %% [markdown]
# ## Save Aggregated Report

# %%
city_sales.to_csv("../data/processed/city_sales_report.csv", index=False)

# %% [markdown]
# ## Conclusion
#
# GroupBy converts row-level data into business insights.
